# %% [markdown]
# # 1. Retrieve Datas from a CSV file

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pymysql

# %%
file = "carData.csv"
car_data_df = pd.read_csv(file)

# %%
car_data_df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# # 2.  Exploring Datas

# %%
car_data_df.shape
# Out:
# (301, 9)

# %%
car_data_df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
car_data_df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
car_data_df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car_data_df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# ### Taille du df

# %%
car_data_df.size
# Out:
# 2709

# %% [markdown]
# ## Données synthétiques d'un df

# %%
car_data_df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# ### Moyenne

# %%
car_data_df.mean()
# Out:
# Year              2013.627907
# Selling_Price        4.661296
# Present_Price        7.628472
# Kms_Driven       36947.205980
# Owner                0.043189
# dtype: float64

# %% [markdown]
# ### Médiane

# %%
car_data_df.median()
# Out:
# Year              2014.0
# Selling_Price        3.6
# Present_Price        6.4
# Kms_Driven       32000.0
# Owner                0.0
# dtype: float64

# %% [markdown]
# ### Quartile

# %%
car_data_df.quantile([0.25, 0.5, 0.75])
# Out:
#         Year  Selling_Price  Present_Price  Kms_Driven  Owner
# 0.25  2012.0            0.9            1.2     15000.0    0.0
# 0.50  2014.0            3.6            6.4     32000.0    0.0
# 0.75  2016.0            6.0            9.9     48767.0    0.0

# %% [markdown]
# ### Minimums

# %%
car_data_df.min()
# Out:
# Car_Name               800
# Year                  2003
# Selling_Price          0.1
# Present_Price         0.32
# Kms_Driven             500
# Fuel_Type              CNG
# Seller_Type         Dealer
# Transmission     Automatic
# Owner                    0
# dtype: object

# %% [markdown]
# ### Maximums

# %%
car_data_df.max(numeric_only=None)
# Out:
# Car_Name              xcent
# Year                   2018
# Selling_Price            35
# Present_Price          92.6
# Kms_Driven           500000
# Fuel_Type            Petrol
# Seller_Type      Individual
# Transmission         Manual
# Owner                     3
# dtype: object

# %% [markdown]
# ## Plotting car_data by distance travelled

# %%
car_data_df['Kms_Driven'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"]=10,10

# %% [markdown]
# ### Opérations sur colonnes df

# %%
car_data_df.Year.unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007])

# %%
car_data_df.Kms_Driven.max()
# Out:
# 500000

# %%
car_data_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Selling_Price'}>],
#        [<AxesSubplot:title={'center':'Present_Price'}>,
#         <AxesSubplot:title={'center':'Kms_Driven'}>],
#        [<AxesSubplot:title={'center':'Owner'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
car_data_df.plot.scatter("Kms_Driven", "Selling_Price", c="Year", colormap='viridis',figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='Kms_Driven', ylabel='Selling_Price'>

# %%
data = car_data_df[car_data_df["Year"]==2008]

# %% [markdown]
# # 3. Load Datas into a DB

# %% [markdown]
# ### MariaDB Connector(test)

# %% [raw]
# import sqlalchemy

# %% [raw]
# #engine = create_engine('mysql+pymsql://root:1mte2rax@localhost/nombdd')
# #path_project = '/~/Code/cardekho/'
# #def loading(path, table):
# #    data = pd.read_csv('carData.csv')
# #    data.to_sql(table, con=engine, if_exists='append', index=False, schema='carData')
# #
# #loading(path_project+'carData.csv', 'cars')

# %% [raw]
# # Module Imports
# import mariadb
# import sys
#
# # Connect to MariaDB Platform
# try:
#     conn = mariadb.connect(
#         user="root",
#         password="1mte2rax",
#         host="localhost",
#         port=3306,
#         database="cardekho"
#     )
# except mariadb.Error as e:
#     print(f"Error connecting to MariaDB Platform: {e}")
#     sys.exit(1)
#
# # Get Cursor
# cur = conn.cursor()

# %% [raw]
# cur.execute(
#     "SELECT * FROM cars")

# %% [raw]
# rec = cur.fetchall()

# %% [raw]
# for row in rec:
#     print("Id = ", row[0], )
#     print("Car Name", row[1], "\n")

# %% [raw]
# finally:
#     if (mariadb.is_connected()):
#         cur.close()
#         conn.close()
#         print("MariaDB is closed")

# %% [markdown]
# ### MySQL Connector(more easy to install and connect to a mariaDB)

# %%
import mysql.connector
try:
    conn = mysql.connector.connect(
        user="root",
        password="1mte2rax",
        host="localhost",
        port=3306,
        database="cardekho"
    )
except mariadb.Error as e:
    print(f"Error connecting to MariaDB Platform: {e}")
    sys.exit(1)


# Get Cursor
cur = conn.cursor()

# %%
cur.execute(
    "SELECT * FROM cars")

# %%
rec = cur.fetchall()

# %%
print(rec)
# Out:
# [(1, 'ritz', 2014, Decimal('3.35'), Decimal('5.590'), 27000, 'Petrol', 'Dealer', 'Manual', 0), (2, 'sx4', 2013, Decimal('4.75'), Decimal('9.540'), 43000, 'Diesel', 'Dealer', 'Manual', 0), (3, 'ciaz', 2017, Decimal('7.25'), Decimal('9.850'), 6900, 'Petrol', 'Dealer', 'Manual', 0), (4, 'wagon r', 2011, Decimal('2.85'), Decimal('4.150'), 5200, 'Petrol', 'Dealer', 'Manual', 0), (5, 'swift', 2014, Decimal('4.60'), Decimal('6.870'), 42450, 'Diesel', 'Dealer', 'Manual', 0), (6, 'vitara brezza', 2018, Decimal('9.25'), Decimal('9.830'), 2071, 'Diesel', 'Dealer', 'Manual', 0), (7, 'ciaz', 2015, Decimal('6.75'), Decimal('8.120'), 18796, 'Petrol', 'Dealer', 'Manual', 0), (8, 's cross', 2015, Decimal('6.50'), Decimal('8.610'), 33429, 'Diesel', 'Dealer', 'Manual', 0), (9, 'ciaz', 2016, Decimal('8.75'), Decimal('8.890'), 20273, 'Diesel', 'Dealer', 'Manual', 0), (10, 'ciaz', 2015, Decimal('7.45'), Decimal('8.920'), 42367, 'Diesel', 'Dealer', 'Manual', 0), (11, 'alto 800', 2017, Decimal('2.85'), Deci
# ...

# %%
cur.close()
conn.close()
print("MariaDB is closed")
# Out:
# MariaDB is closed

# %% [markdown]
# ## Loading Datas w PyMySQL & SQLAlchemy

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://dan:sac0uwv0@localhost/cardb")
df = pd.read_sql_table('cardata',engine)

# %%
df
# Out:
#      index Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0        0     ritz  2014           3.35           5.59       27000    Petrol
# 1        1      sx4  2013           4.75           9.54       43000    Diesel
# 2        2     ciaz  2017           7.25           9.85        6900    Petrol
# 3        3  wagon r  2011           2.85           4.15        5200    Petrol
# 4        4    swift  2014           4.60           6.87       42450    Diesel
# ..     ...      ...   ...            ...            ...         ...       ...
# 296    296     city  2016           9.50          11.60       33988    Diesel
# 297    297     brio  2015           4.00           5.90       60000    Petrol
# 298    298     city  2009           3.35          11.00       87934    Petrol
# 299    299     city  2017          11.50          12.50        9000    Diesel
# 300    300     brio  2016           5.30           5.90        5464    Petrol
#
# ...

# %% [raw]
# I've added Index column for security and recommended data structure

# %% [markdown]
# # 4. Displaying these Datas w Seaborn

# %%
import seaborn as sns
sns.color_palette("viridis")
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(x='Year', y='Selling_Price', data=df, width=0.5)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Selling_Price'>

# %%
graph_1 = sns.catplot(x="Present_Price", y="Selling_Price", data=df, height=5, aspect=2)

# %%
sns.heatmap(df.corr(), annot=True, cmap='magma')
plt.title("Matrice de corrélation entre les différentes caractéristiques des annoncées\n", fontsize=18, color='#009432')
# Out:
# Text(0.5, 1.0, 'Matrice de corrélation entre les différentes caractéristiques des annoncées\n')

# %% [markdown]
# # 4. Quantify Datas between Age & Selling price

# %%
sns.set(font_scale=1.5,style="whitegrid")
g = sns.lmplot(x="Year",y="Selling_Price",data=df, line_kws={'color': 'red'})

# %% [markdown]
# ## 4.1 Linear Regression w NumPy

# %%
x = df['Year']
y = df['Selling_Price']
plt.scatter(x, y) # Nuage de points
pf = np.polyfit(x, y, 1)
p1d = np.poly1d(pf)

plt.plot(x, p1d(x), color='red')

# %%
print(p1d(2050)*1000)
# Out:
# 19759.049411528053

# %%
#test reshape
a = [[1, 2, 3], [4, 5, 6]]
c = np.reshape(a,(3,2))
print(c)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %% [markdown]
# ## 4.2 Linear Regression w SciPy

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

plt.plot(x, y,'o', label='original data')
plt.plot(x, slope*x + intercept, color="red", label='fitted line' )
plt.show()
print("slope: %f    intercept: %f" % (slope, intercept))
print("R-squared: %f" % r_value**2)
# Out:
# slope: 0.415092    intercept: -831.178925
# R-squared: 0.055763

# %% [markdown]
# ### SP Prediction for 2050

# %%
(intercept + 2050 * slope)*1000
# Out:
# 19759.049411527827

# %% [markdown]
# ## 4.3 Linear Regression avec Sklearn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://dan:sac0uwv0@localhost/cardb")
df = pd.read_sql_table('cardata',engine)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(df[["Year"]], df[["Selling_Price"]], test_size=0.2,random_state = 42)
lr = LinearRegression()
lr = lr.fit(xtrain[["Year"]], ytrain)
p = lr.predict(xtest[["Year"]])

plt.plot(xtest[["Year"]], ytest, 'o')
plt.plot(xtest[["Year"]], p, color="red")

# %% [markdown]
# ### SKL Prediction for 2050

# %%
float(lr.predict([[2050]]))*1000
# Out:
# 18888.524611455865

# %% [markdown]
# ## 4.4 Improve the model using multiple input variables

# %%
# Need to convert Transmission strings to vector
Transm = pd.get_dummies(df['Transmission'].astype(str))
# print('Our multiple linear model had an R^2 of: %0.3f'%multiple.score(x, y)) #Donne le score total du modèle

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
ax.scatter(df["Year"], df["Selling_Price"], df["Kms_Driven"], c=df["Kms_Driven"], cmap="viridis")
ax.set_xlabel('Year')
ax.set_ylabel('Selling_Price')
ax.set_zlabel('Kms_Driven')
 
plt.show()

# %% [markdown]
# ## 4.5 Conclusion

# %% [markdown]
# The data do not exactly describe a modeling line and the various library tests have only shown this point in agreement with the data correlation matrix.
#
# Each model has its own learning algorithm and it is appropriate here to choose a model with discrete values or groups of continuous models.
#
# The models in vogue today are the random forests. They accommodate discrete or continuous variables and missing values. This is not the case of neural networks and SVM which have gone out of fashion even if they are coming back to the forefront with the Deep Neural Network.

# %% [markdown]
# # 5 Own design of a Python's LinearRegression Class

# %%
# Caroline Cao
slop=((y-y.mean())*(x-x.mean())).sum()/(((x-x.mean())**2).sum())

# %%
x = df['Year']
y = df['Selling_Price']
X = df['Year']
Y = df["Selling_Price"]

class MyLinReg:
    def __init(self):
        self.x = x
        self.y = y
    
    def myfit(self,x,y):
        slop=((y-y.mean())*(x-x.mean())).sum()/(((x-x.mean())**2).sum())
        intercept=y.mean()-(slop*x.mean())
        return slop,intercept
    
    def mypredict(self,a):
        self.myfit(x,y)
        pred = self.myfit(x,y)[0]*a + self.myfit(x,y)[1]
        return pred

# %%
z = MyLinReg()
float(z.mypredict(2050)*1000)
# Out:
# 19759.049411527827

# %% [markdown]
# # 6 Support Vector Machine

# %% [markdown]
# The Support Vector Machine seems only appropriate to treat specific type of datas
# It can (only!) easily handle multiple continuous and categorical variables.
# By ie, it can be applyied on the Transmission column

# %%
xtrain, xtest, ytrain, ytest = train_test_split(df[["Transmission"]], df[["Selling_Price"]], test_size=0.2,random_state = 42)
x = df['Transmission']
y = df['Selling_Price']
from sklearn.model_selection import train_test_split
training_set, test_set = train_test_split(df, test_size = 0.2, random_state = 1)

# %%
X_train = training_set.x.values
Y_train = training_set.y.values
X_test = test_set.x.values
Y_test = test_set.y.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-0ec13b8fdafa> in <module>
# ----> 1 X_train = training_set.x.values
#       2 Y_train = training_set.y.values
#       3 X_test = test_set.x.values
#       4 Y_test = test_set.y.values
#
# ~/anaconda3/envs/cardekho/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'x'

# %% [markdown]
# # 8 Dashboard

# %%
#pip install dash==1.17.0

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

def generate_table(dataframe, max_rows=10):
    return html.Table([
        html.Thead(
            html.Tr([html.Th(col) for col in dataframe.columns])
        ),
        html.Tbody([
            html.Tr([
                html.Td(dataframe.iloc[i][col]) for col in dataframe.columns
            ]) for i in range(min(len(dataframe), max_rows))
        ])
    ])

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

app.layout = html.Div(children=[
    html.H4(children=''),
    generate_table(df)
])

if __name__ == '__main__':
    app.run_server(debug=True)
